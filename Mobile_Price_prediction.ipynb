# %% [markdown]
# <a href="https://colab.research.google.com/github/skr2rathishan-oss/AI-ML--Projects/blob/main/Mobile_Price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
# !pip install tensorflow pandas scikit-learn

# %%
import pandas as pd
import numpy as np
import sklearn
import tensorflow as tf

# %% [markdown]
# ## Read CSV

# %%
pf=pd.read_csv("/content/sample_data/Mobile_Price_Classification-220531-204702.csv")
pf.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# # Split the data in to independent & dependent variable

# %%
x = pf.drop('price_range', axis=1)
y = pf['price_range']

# %% [markdown]
# # Train & Test the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.25)

# %% [markdown]
# # Normalize the Data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Build the ANN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential([Dense(8,input_dim=X_train.shape[1],activation='relu'),
                  Dense(4,activation='relu'),
                  Dense(1,activation='sigmoid')
                  ])

# %% [markdown]
# # Compile and Train the Model

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
history=model.fit(X_train,Y_train,
                  epochs=100,
                  batch_size=32,
                  validation_data=(X_test,Y_test))
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4617 - loss: 0.7469 - val_accuracy: 0.4820 - val_loss: 0.7206
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4957 - loss: 0.7106 - val_accuracy: 0.5020 - val_loss: 0.7039
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5129 - loss: 0.6926 - val_accuracy: 0.5140 - val_loss: 0.6940
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5350 - loss: 0.6841 - val_accuracy: 0.5520 - val_loss: 0.6878
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5739 - loss: 0.6776 - val_accuracy: 0.5740 - val_loss: 0.6822
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5934 - loss: 0.6646 - val_accuracy: 0.5740 - val_loss: 0.6764
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6318 - loss: 0.6621 - val_accuracy: 0.5920 - val_loss: 0.6705
# Epoch 8/100
# ...

# %%
loss,accuracy=model.evaluate(X_test,Y_test)
print(f"Test Accuracy:{accuracy*100:2f}%")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.3552
# Test Accuracy:86.600000%
